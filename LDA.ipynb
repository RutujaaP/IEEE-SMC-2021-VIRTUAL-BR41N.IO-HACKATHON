# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
X_train = np.load("/content/drive/MyDrive/2021_VIIT_P300_Session2 /Hackathon Oct 2021/XDawn/X.npy")
X_test = np.load("/content/drive/MyDrive/2021_VIIT_P300_Session2 /Hackathon Oct 2021/XDawn/X_test.npy")
Y_train = np.load("/content/drive/MyDrive/2021_VIIT_P300_Session2 /Hackathon Oct 2021/XDawn/Y.npy")
Y_test = np.load("/content/drive/MyDrive/2021_VIIT_P300_Session2 /Hackathon Oct 2021/XDawn/Y_test.npy")
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((5670, 528), (3780, 528), (5670,), (3780,))

# %%
# print(X_train.shape,Y_train.shape)
# X_train_new = np.concatenate((X_train,np.reshape(Y_train,(5670,1))),axis=1)
# X_test_new = np.concatenate((X_test,np.reshape(Y_test,(3780,1))),axis=1)
# print(X_train_new.shape,X_test_new.shape)
data_X = np.concatenate((X_train,X_test),axis=0)
data_Y=np.concatenate((Y_train,Y_test),axis=0)
print(data_X.shape)
print(data_Y.shape)
# Out:
# (9450, 528)
# (9450,)

# %%
from sklearn.model_selection import KFold

# %%
k=10

# %%
kf = KFold(n_splits = k, shuffle = False)
for train_index, test_index in kf.split(data):
    
    xTrain = data_X[train_index]
    xTest = data_X[test_index]
    yTrain = data_Y[train_index]
    yTest = data_Y[test_index]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix

# %%
ldaClf = LinearDiscriminantAnalysis()
ldaClf.fit(xTrain, yTrain.ravel())
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
predictedLabel= ldaClf.predict(xTest)
[[tn, fp],[fn, tp]] = confusion_matrix(yTest.ravel(), predictedLabel)
print(f"tp: {tp}") 
print(f"fp: {fp}")
print(f"tn: {tn}") 
print(f"fn: {fn}") 
accuracy = (tp+tn)/(tp+tn+fp+fn)
accuracy
# Out:
# tp: 739
# fp: 0
# tn: 0
# fn: 206
# 0.782010582010582

# %%
predictedLabel= ldaClf.predict(xTrain)
[[tn, fp],[fn, tp]] = confusion_matrix(yTrain.ravel(), predictedLabel)
print(f"tp: {tp}") 
print(f"fp: {fp}")
print(f"tn: {tn}") 
print(f"fn: {fn}") 
accuracy = (tp+tn)/(tp+tn+fp+fn)
accuracy
# Out:
# tp: 2752
# fp: 435
# tn: 4815
# fn: 503
# 0.8897119341563786

# %% [markdown]
# STEPWISE LDA ka link- https://github.com/taliastocks/Py3GUI/blob/master/swlda.py
